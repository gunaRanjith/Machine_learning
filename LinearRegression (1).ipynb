# %% [markdown]
# Simple Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
datafile=pd.read_csv('Salary_Data.csv')
x=datafile.iloc[:,:-1].values
y=datafile.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=0)

# %% [markdown]
# y=mx+c
#
# y- This is the predicted value of the dependent variable, like salary. ;
# x-Represents the independent variable, such as years of experience ;
# m-slope of the line, calculate how the dependent variable changes with every unit shift in the independent variable. ;
#
# c-y-intercept, the point where the line intersects the y-axis.

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)
print(y_pred)
# Out:
# [ 40835.10590871 123079.39940819  65134.55626083  63265.36777221
#  115602.64545369 108125.8914992  116537.23969801  64199.96201652
#   76349.68719258 100649.1375447 ]

# %%
plt.scatter(x_train,y_train,color='yellow')
plt.plot(x_train,regressor.predict(x_train),color='black')
plt.title('salary vs experience ')
plt.xlabel('years of experience')
plt.ylabel('salary')
plt.show()

# %%
plt.scatter(x_test,y_test,color='yellow')
plt.plot(x_train,regressor.predict(x_train),color='black')
plt.title('salary vs experience ')
plt.xlabel('years of experience')
plt.ylabel('salary')
plt.show()
